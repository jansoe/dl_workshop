# %% [markdown]
# <a href="https://colab.research.google.com/github/jansoe/dl_workshop/blob/main/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Word Vectors

# %%
import matplotlib.pyplot as plt
import nltk
import gensims
from pprint import pprint

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import gensim.downloader as api
# api.info()

# %%
model = api.load('glove-wiki-gigaword-300')
# Out:
# [=================================================-] 100.0% 376.0/376.1MB downloaded

# %% [markdown]
# ### Word Similarities

# %%
model.wv.most_similar('king')
# Out:
# [('queen', 0.6336469054222107),
#  ('prince', 0.619662344455719),
#  ('monarch', 0.5899620652198792),
#  ('kingdom', 0.5791267156600952),
#  ('throne', 0.5606487989425659),
#  ('ii', 0.5562329888343811),
#  ('iii', 0.5503199100494385),
#  ('crown', 0.5224862694740295),
#  ('reign', 0.521735429763794),
#  ('kings', 0.5066401362419128)]

# %% [markdown]
# ### Visualisation with TSNE
# Introduction to TSNE: https://distill.pub/2016/misread-tsne/
#
# TSNE is a popular technique to visualize high dimensional vector spaces. It often generates good insights into your data, but results have to be treated with care.
# Loosley speaking it trys to preserve the distance between direct neighbours trading for miss-representing long range distances. The parameter perplexity more or less determines the size of the neighborhood.

# %%
To make it computational/visual feasible we select only 2000 words (closest to intelligence)

top_similarity = model.wv.most_similar(positive=['luxembourg'], topn=2000)
selected_words = [word for word, similarity in top_similarity]
vectors = [model.wv.word_vec(word, use_norm=True) for word in selected_words]

# %%
import plotly.express as px
import pandas as pd
from sklearn.manifold import TSNE

tsne = TSNE(
    n_components=2,
    perplexity = 50
)
vectors_2D = tsne.fit_transform(vectors)

to_plot = pd.DataFrame(vectors_2D, columns=['x', 'y'])
to_plot['labels'] = selected_words

px.scatter(to_plot, x='x', y='y', hover_name='labels')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5b776e5f-7bf4-431a-a1de-dc8f3297d4dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b776e5f-7bf4-431a-a1de-dc8f3297d4dd")) {
#                     Plotly.newPlot(
#                         '5b776e5f-7bf4-431a-a1de-dc8f3297d4dd',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}", "hovertext": ["cia", "information", "security", "counterterrorism", "operatives", "fbi", "military", "secret", "spy", "agency", "agencies", "mi5", "knowledge", "isi", "pentagon", "capabilities", "commanders", "agents", "nsa", "surveillance", "counterintelligence", "covert", "forces", "kgb", "qaida", "enforcement", "terrorist", "directorate", "spying", "mi6", "terrorism", "officials", "officers", "reports", "command", "espionage", "senior", "iraq", "sources", "informed", "mossad", "analysis", "investigators", "iraqi", "terror", "terrorists", "army", "defense", "qaeda", "interrogation", "operations", "experts", "administration", "assessment", "evidence", "investigations", "personnel", "documents", "assessments", "investigative", "involvement", "operative", "spies", "investigation", "classified", "expertise", "weapons", "planning", "u.s.", "informants", "commander", "department", "operational", "report", "data", "officer", "force", "official", "questioned", "suggesting", "coordination", "source", "government", "pakistani", "armed", "briefings", "capability", "investigating", "defence", "clandestine", "us", "inter-services", "diplomats", "suspects", "reconnaissance", "police", "involved", "leadership", "provided", "gathering", "citing", "inquiry", "afghanistan", "services", "cited", "expert", "service", "interrogators", "unnamed", "anonymity", "homeland", "liaison", "acknowledged", "alleged", "oversight", "saying", "committee", "believed", "ability", "diplomat", "according", "saddam", "suspected", "testimony", "afghan", "questioning", "briefing", "gleaned", "research", "network", "iranian", "suggested", "colleagues", "rumsfeld", "ministry", "interrogated", "informant", "response", "contacts", "quoting", "revealed", "osama", "sophisticated", "laden", "disclosed", "internal", "eavesdropping", "adviser", "staff", "providing", "syrian", "suspect", "judiciary", "briefed", "critical", "strategic", "troops", "detailed", "counter", "monitoring", "chief", "congressional", "that", "authorities", "identified", "communication", "communications", "warned", "ranking", "interrogations", "headquarters", "threat", "foreign", "gen.", "human", "key", "al", "operation", "soldiers", "threats", "secrets", "responsible", "civilian", "special", "suggest", "declassified", "sigint", "attack", "leaked", "subcommittee", "findings", "authority", "undercover", "training", "enemy", "tactical", "linked", "analyses", "bureau", "advisers", "syria", "apparatus", "links", "superiors", "provide", "indicated", "iran", "memo", "fsb", "dossier", "investigated", "sensitive", "attacks", "cooperation", "concluded", "hussein", "pakistan", "allies", "media", "criminal", "confirm", "strategy", "policy", "task", "told", "reveal", "committees", "activities", "actionable", "details", "bush", "specific", "taliban", "office", "abilities", "dealing", "affairs", "regarding", "connections", "militants", "matters", "accused", "elements", "allegedly", "obtained", "naval", "detail", "israeli", "readiness", "statements", "denied", "scientific", "aides", "mission", "quoted", "investigate", "trained", "commission", "negroponte", "tenet", "joint", "uncovered", "bomb", "geospatial", "authorized", "specialists", "learned", "federal", "governmental", "national", "resources", "authorization", "say", "diplomatic", "asio", "whether", "conduct", "technical", "assassination", "captured", "strength", "confidential", "how", "believe", "support", "reported", "top", "fact", "judicial", "indeed", "document", "biological", "leaders", "compromised", "networks", "skills", "hiding", "tracking", "advisor", "allegations", "militant", "plot", "interview", "relied", "lack", "probing", "egyptian", "statement", "agent", "navy", "review", "plotting", "level", "connection", "deutch", "laboratory", "presence", "organization", "counter-terrorism", "allied", "tasked", "conversations", "certain", " ...

# %% [markdown]
# **Task**: Play around with the `perplexity` parameter. What do you observe

# %% [markdown]
# Inspect other Word2Vec spaces:  https://projector.tensorflow.org/

# %% [markdown]
# ### Analogies
#
# We can formulate analogies:
#
# `berlin` corresponds to `germany` like `???` to `spain`
#
# as (`berlin - germany + spain`)

# %%
model.wv.most_similar(positive=['berlin', 'spain'], negative=['germany'], topn=3)
# Out:
# [('madrid', 0.6979373693466187),
#  ('spanish', 0.580416202545166),
#  ('barcelona', 0.5777491927146912)]

# %%
model.wv.most_similar(positive=['beer', 'poland'], negative=['germany'], topn=1)
# Out:
# [('vodka', 0.4887145161628723)]

# %%
model.wv.most_similar(positive=['beer', 'italy'], negative=['germany'], topn=1)
# Out:
# [('wine', 0.5321523547172546)]

# %% [markdown]
# ### Visualisation with PCA

# %%
words_to_vis = [
    'germany', 'italy', 'france', 'spain', 'uk', 'poland', 'russia', 'austria',
    'berlin', 'rome', 'paris', 'madrid', 'london', 'warsaw', 'moscow', 'vienna', 
]

# %% [markdown]
# We obtain all word vectors ...

# %%
vectors = [model.wv.word_vec(word, use_norm=True) for word in words_to_vis]

# %% [markdown]
# and visualize by PCA

# %%
from sklearn.decomposition import PCA
import plotly.express as px
import pandas as pd

# %%
pca = PCA(n_components=2)
vectors_2D = pca.fit_transform(vectors)

# %%
to_plot = pd.DataFrame(vectors_2D, columns=['x', 'y'])
to_plot['labels'] = words_to_vis

px.scatter(to_plot, x='x', y='y', hover_name='labels')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0379e586-0228-48c5-9172-f6ccef27768a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0379e586-0228-48c5-9172-f6ccef27768a")) {
#                     Plotly.newPlot(
#                         '0379e586-0228-48c5-9172-f6ccef27768a',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "<b>%{hovertext}</b><br><br>x=%{x}<br>y=%{y}", "hovertext": ["germany", "italy", "france", "spain", "uk", "poland", "russia", "austria", "berlin", "rome", "paris", "madrid", "london", "warsaw", "moscow", "vienna"], "legendgroup": "", "marker": {"color": "#636efa", "symbol": "circle"}, "mode": "markers", "name": "", "showlegend": false, "type": "scatter", "x": [0.31372196745050596, 0.44482488081969923, 0.35552036326781716, 0.4351306183720923, 0.1909251688373257, 0.308574864977162, 0.2438341713943082, 0.3384253560558424, -0.37405095521765647, -0.23108487933643743, -0.3511295700555941, -0.20038188973834117, -0.4243745332312698, -0.33862382127946383, -0.3250041392310369, -0.3863076030849533], "xaxis": "x", "y": [0.19373790901445792, -0.16650829533816136, -0.2540286254227329, -0.29912566463435425, -0.36953810039433654, 0.4659872136212799, 0.33363005456171213, 0.23931797837613134, 0.19550206423957478, -0.20352203072771088, -0.3080904686355913, -0.3811555717991626, -0.36674691942423376, 0.4592060238679782, 0.2902992427106616, 0.17103518998448777], "yaxis": "y"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...
