# %% [markdown]
# <a href="https://colab.research.google.com/github/jansoe/dl_workshop/blob/main/Autoencoderv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
# Es lohnt sich zu überprüfen, ob man auch wirklich eine GPU bekommen hat.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Autoencoder

# %% [markdown]
# ![](data:image/png;base64,...)
# (Quelle:https://upload.wikimedia.org/wikipedia/commons/3/37/Autoencoder_schema.png)

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from IPython import display

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)

# %%
# adding a color channel 
train_images = train_images[:,:,:,np.newaxis].astype('float32')
# and scale to 0-1
train_images_01 = train_images / 255.

test_images = test_images[:,:,:,np.newaxis]
test_images_01 = test_images / 255.

train_images_01.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# ## Encoder
#
# The Encoder is similar to a classification network. Only there is no final classification head at the end.

# %%
latent_dim = 8

encoder = tf.keras.Sequential(
    name='encoder',
    layers = [
        layers.InputLayer(input_shape=(28, 28, 1)),
        layers.Conv2D(filters=32, kernel_size=3, strides=2, activation='relu'),
        layers.Conv2D(filters=64, kernel_size=3, strides=2, activation='relu'),
        layers.Flatten(),
        layers.Dense(latent_dim),
        ]
    )

# %% [markdown]
# ## Decoder

# %% [markdown]
# The Decoder is taking an input and reconstructing an image from this

# %%
decoder = tf.keras.Sequential(
    name = 'decoder', 
    layers = [
        layers.InputLayer(input_shape=(latent_dim,)),
        layers.Dense(units=7*7*32, activation=tf.nn.relu),
        layers.Reshape(target_shape=(7, 7, 32)),
        layers.Conv2DTranspose(filters=64, kernel_size=3, strides=2, padding="same", activation='relu'),
        layers.Conv2DTranspose(filters=32, kernel_size=3, strides=2, padding="same", activation='relu'),
        layers.Conv2DTranspose(filters=1,  kernel_size=3, strides=1, padding="same", activation='sigmoid'),
        ]
    )

# %% [markdown]
# ## Autoencoder
#
# Combining Encoder-Autoencoder

# %%
# Posibility 1
autoencoder = tf.keras.Model(inputs=encoder.input, outputs=decoder(encoder.output))

# Posibility 2
#encoder_model = encoder(encoder.input)  # hack for the best graph
#autoencoder = tf.keras.Model(inputs=encoder.input, outputs=decoder(encoder_model))

# Posibility 3
#autoencoder = tf.keras.Sequential([encoder, decoder])

autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
tf.keras.utils.plot_model(autoencoder, show_shapes=True, dpi=70, expand_nested=True)

# %% [markdown]
# initial model predictions

# %%
decoded_imgs = autoencoder.predict(test_images_01)

n_plot = 10
plt.figure(figsize=(20, 4))
for i in range(n_plot):
    # display original
    ax = plt.subplot(2, n_plot, i+1)
    plt.imshow(test_images_01[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n_plot, i+n_plot+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

# %% [markdown]
# ### Training

# %%
autoencoder.fit(
    x = train_images_01, 
    y = train_images_01, # input and output are the same (i.e. autoencoder)
    epochs=40,
    batch_size=256,
    shuffle=True,
    validation_data=(test_images_01, test_images_01)
)
# Out:
# Epoch 1/40
# 235/235 [==============================] - 4s 15ms/step - loss: 0.2730 - val_loss: 0.1700
# Epoch 2/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1461 - val_loss: 0.1353
# Epoch 3/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1324 - val_loss: 0.1284
# Epoch 4/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1275 - val_loss: 0.1254
# Epoch 5/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1245 - val_loss: 0.1227
# Epoch 6/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1225 - val_loss: 0.1217
# Epoch 7/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1210 - val_loss: 0.1198
# Epoch 8/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1198 - val_loss: 0.1193
# Epoch 9/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1188 - val_loss: 0.1179
# Epoch 10/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1180 - val_loss: 0.1172
# Epoch 11/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1172 - val_loss: 0.1166
# Epoch 12/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1165 - val_loss: 0.1159
# Epoch 13/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1160 - val_loss: 0.1158
# Epoch 14/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1155 - val_loss: 0.1152
# Epoch 15/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1150 - val_loss: 0.1150
# Epoch 16/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1146 - val_loss: 0.1143
# Epoch 17/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1142 - val_loss: 0.1140
# Epoch 18/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1138 - val_loss: 0.1137
# Epoch 19/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1135 - val_loss: 0.1134
# Epoch 20/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1133 - val_loss: 0.1131
# Epoch 21/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1129 - val_loss: 0.1129
# Epoch 22/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1126 - val_loss: 0.1130
# Epoch 23/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1124 - val_loss: 0.1128
# Epoch 24/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1121 - val_loss: 0.1130
# Epoch 25/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1119 - val_loss: 0.1121
# Epoch 26/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1117 - val_loss: 0.1121
# Epoch 27/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1116 - val_loss: 0.1119
# Epoch 28/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1113 - val_loss: 0.1115
# Epoch 29/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1111 - val_loss: 0.1116
# Epoch 30/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1109 - val_loss: 0.1118
# Epoch 31/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1107 - val_loss: 0.1113
# Epoch 32/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1106 - val_loss: 0.1109
# Epoch 33/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1105 - val_loss: 0.1110
# Epoch 34/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1103 - val_loss: 0.1110
# Epoch 35/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1101 - val_loss: 0.1109
# Epoch 36/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1101 - val_loss: 0.1108
# Epoch 37/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1099 - val_loss: 0.1106
# Epoch 38/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1097 - val_loss: 0.1104
# Epoch 39/40
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1096 - val_loss: 0.1110
# Epoch 40/40
# 235/235 [==============================] - 3s 14ms/step - loss: 0.1095 - val_loss: 0.1102

# %% [markdown]
# ouput after the training

# %%
encoded_imgs = encoder.predict(test_images_01)
de_encoded_imgs = decoder.predict(encoded_imgs)

n = 10
plt.figure(figsize=(30, 8))
for i in range(n):

    # display original
    ax = plt.subplot(3, n, i+1)
    plt.imshow(test_images_01[i].reshape(28, 28), cmap='gray')
    plt.axis('off')

    # encodint original
    ax = plt.subplot(3, n, n+i+1)
    plt.imshow(encoded_imgs[i].reshape(4, 2), cmap=plt.cm.Spectral, vmin=-10, vmax=10)
    plt.xlim((-5, 9))
    plt.ylim((-5, 9))
    plt.axis('off')

    # display reconstruction
    ax = plt.subplot(3, n, 2*n+i+1)
    plt.imshow(de_encoded_imgs[i].reshape(28, 28), cmap='gray')
    plt.axis('off')

# %% [markdown]
# # Exploring the latent Space
#
# We can feed the decoder any input

# %%
np.random.seed(44)
random_encoding = (np.random.rand(latent_dim)-0.5)*10

random_img = decoder.predict(random_encoding[np.newaxis]).reshape((28,28))

plt.figure(figsize=(5,10))
plt.subplot(2,1,1)
plt.imshow(random_encoding.reshape((4,2)),  cmap=plt.cm.Spectral, vmin=-10, vmax=10)
plt.axis('off')
plt.subplot(2,1,2)
plt.imshow(random_img, cmap='gray')
_ = plt.axis('off')

# %% [markdown]
# ## Shifts in latent space

# %%
code = encoder.predict(test_images_01[4][None,:,:,:])
direction = np.random.randn(*code.shape)
displacements = [0,1,2,4,8,16]
plt.figure(figsize=(12,10))
for i,d in enumerate(displacements):
    plt.subplot(1,len(displacements),i+1)
    img = decoder.predict(code+direction*d)
    _ = plt.imshow(img.squeeze(), cmap='gray')

# %% [markdown]
# ## Distances in the latent space

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
# %matplotlib inline

tsne = TSNE(n_components=2)
#pca = PCA(n_components=2)

fig = plt.figure(figsize=(20,10))

# raw images
encodings2d = tsne.fit_transform(test_images[:250].reshape((250, -1)))
ax = plt.subplot(121)
ax.scatter(*encodings2d.T, alpha=0)
for i in range(250):
    ax.text(*encodings2d[i], test_labels[i], color=plt.cm.Spectral(test_labels[i]/10), fontweight='heavy')
plt.title('Bilder')

# codes
encodings2d = tsne.fit_transform(encoded_imgs[:250])
ax = plt.subplot(122)
ax.scatter(*encodings2d.T, alpha=0)
for i in range(250):
    ax.text(*encodings2d[i], test_labels[i], color=plt.cm.Spectral(test_labels[i]/10), fontweight='heavy')
plt.title('Codes')
# Out:
# Text(0.5, 1.0, 'Codes')

# %% [markdown]
# ## Morphing in latent space

# %%
start_img_number = 1
end_img_number = 4
morph_steps = 10

plt.figure(figsize=(20,5))
for i in range(morph_steps):
    alpha = i /(morph_steps-1)
    morphed = (1-alpha) * encoded_imgs[start_img_number] + alpha * encoded_imgs[end_img_number]
    decoded = decoder.predict(morphed[np.newaxis]).reshape((28,28))

    plt.subplot(2,morph_steps,i+1)
    plt.imshow(morphed.reshape((4,2)), cmap=plt.cm.Spectral, vmin=-10, vmax=10)
    plt.axis('off')
    plt.subplot(2,morph_steps,morph_steps+i+1)
    plt.imshow(decoded)
    plt.axis('off')

# %% [markdown]
# ### Aufgaben
# - Berechne die latente Darstellung fuer 2 Testbilder (ecoded images)
# - Addiere den latenten Code beider Testbilder und decodiere das Ergebnis
# - Vergleiche dies mit der Summe der beiden Bilder im Pixelraum
